# %% [markdown]
# # Processing of Party Text Programs to get Word Usage Count

# %% [markdown]
# ## Import the relevant libraries

# %%
import pandas as pd
import numpy as np
from collections import defaultdict

# %%
Partidos = ["BE", "PAN", "PCP", "L", "CH", "PS", "IL", "PEV", "AD"]

# %%
ToExclude = pd.read_csv('2Exclude.txt')
ToExclude
# Out:
#     2Exclude
# 0      bloco
# 1         pp
# 2        vii
# 3       três
# 4       seis
# ..       ...
# 125      cdu
# 126       ad
# 127        º
# 128        ª
# 129        á
#
# [130 rows x 1 columns]

# %% [markdown]
# ## Go through text and count word usage paragraph by paragraph

# %%
def CountSequences(words,n):
#Given a list, returns a dictionary mapping each n-element sequence tuple to its number of occurrences in the list.
# Initialize all counts implicitly to 0.
    countDict = defaultdict(int)

    for i in range(len(words)-n+1):
        key = tuple(words[i:i+n])
        countDict[key] = countDict[key] + 1
    return countDict

# %%
FullWordList = pd.DataFrame(columns = ['Word', 'Partido'])
ProcessedInput = pd.DataFrame(columns = ['Word', 'Partido', 'Q_Words', 'Count'])            

for Partido in ["PEV", "Livre"]: #Partidos:
    print(Partido+'.txt')
    
    with open(Partido+'.txt', encoding='utf-8-sig') as fp:
        
        line = fp.readline()

        while line:
            
            line = line.lower()
            
            for ToExcludeWord in ToExclude['2Exclude']:
                line = line.replace(" "+ToExcludeWord+" ", " ")
                if line[0:len(ToExcludeWord)+1] == ToExcludeWord+" ":
                    line = line[len(ToExcludeWord)+1:len(line)]
                if line[len(line)-len(ToExcludeWord)-2:len(line)-1] == " "+ToExcludeWord:
                    line = line[0:len(line)-len(ToExcludeWord)-2]+"\n"
            
            line = line.strip()
            Words = line.split()

            for Group in range (3):
                ToExport = CountSequences(Words,Group+1)
                ToExportKeys = ToExport.keys()
                for i in ToExportKeys:
                    ProcessedInput = ProcessedInput.append({'Word': ' '.join(i), 
                                                            'Partido' : Partido, 
                                                            'Q_Words' : Group+1, 
                                                            'Count': ToExport[i]},
                                                          ignore_index = True)
                    
            line = fp.readline()
        
    fp.close()
    
ProcessedInput
# Out:
# PEV.txt
# Livre.txt
#                        Word Partido Q_Words Count
# 0                 manifesto     PEV       1     1
# 1                ecologista     PEV       1     1
# 2      manifesto ecologista     PEV       2     1
# 3                 recuperar     PEV       1     1
# 4                       voz     PEV       1     1
# ...                     ...     ...     ...   ...
# 83248               janeiro   Livre       1     1
# 83249            28 janeiro   Livre       2     1
# 83250                   www   Livre       1     1
# 83251          partidolivre   Livre       1     1
# 83252                    pt   Livre       1     1
#
# [83253 rows x 4 columns]

# %% [markdown]
# ## Save as previous process is very slow

# %%
ProcessedInput.to_csv('Processed PEV+Livre.txt', index=True, mode='w', header=True, encoding='utf-8-sig')

# %% [markdown]
# ## Nice place to restart run if data was saved

# %%
ProcessedPast = pd.read_csv('Processed BE+PAN+PCP+L+CH+PS+IL+PEV+AD.txt')
FullWordList = ProcessedPast

# %%
# Code to concatenate previous processing (as that is very slow execution pre-processing may by done in chunks)
ProcessedPast = pd.read_csv('Processed BE+PCP+IL.txt')
FullWordList = pd.concat([ProcessedInput,ProcessedPast])
FullWordList.to_csv('Processed BE+PCP+IL+PEV+Livre.txt', index=True, mode='w', header=True, encoding='utf-8-sig')
FullWordList
# Out:
#                                          Word Partido Q_Words Count  \
# 0                                   manifesto     PEV       1     1
# 1                                  ecologista     PEV       1     1
# 2                        manifesto ecologista     PEV       2     1
# 3                                   recuperar     PEV       1     1
# 4                                         voz     PEV       1     1
# ...                                       ...     ...     ...   ...
# 349403                       mundo mais justo     PCP       3     1
# 349404                    mais justo pacífico     PCP       3     1
# 349405            justo pacífico desenvolvido     PCP       3     1
# 349406      pacífico desenvolvido sustentável     PCP       3     1
# 349407  desenvolvido sustentável progressista     PCP       3     1
#
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1
# 0              NaN           NaN             NaN
# 1              NaN           NaN             NaN
# 2              NaN           NaN             NaN
# 3              NaN           NaN             NaN
# 4              NaN           NaN             NaN
# ...            ...           ...             ...
# 349403    273043.0      164802.0        164802.0
# 349404    273044.0      164803.0        164803.0
# 349405    273045.0      164804.0        164804.0
# 349406    273046.0      164805.0        164805.0
# 349407    273047.0      164806.0        164806.0
#
# [432661 rows x 7 columns]

# %% [markdown]
# ## Calculate Party Program word size

# %%
PartidoStats = FullWordList[FullWordList.Q_Words==1.0].groupby(['Partido']).count()
PartidoStats.rename(columns={"Q_Words": "Count_Words"}, inplace=True)
PartidoStats.drop('Word', axis = 1, inplace=True)
PartidoStats.drop('Count', axis = 1, inplace=True)
PartidoStats
# Out:
#          Count_Words  Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1
# Partido
# BE             36826       36826         36826           36826
# IL             38357       38357         38357               0
# Livre          35481           0             0               0
# PCP            22598       22598         22598           22598
# PEV             1410           0             0               0

# %% [markdown]
# ## Synonyms are use to consolidate words with same "meaning"

# %%
SynonymsCustom = pd.read_csv('Synonyms Custom.txt')
SynonymsDictionary = pd.read_csv('Synonyms Dictionary.txt')

SynonymsDictionaryFiltered = SynonymsDictionary.loc[SynonymsDictionary['Word2']!=""]
SynonymsDictionaryFiltered = SynonymsDictionary.loc[SynonymsDictionaryFiltered['Word2'].notnull()]
SynonymsDictionaryFiltered = SynonymsDictionaryFiltered.loc[SynonymsDictionaryFiltered['Word2']!=SynonymsDictionaryFiltered["Word"]]
Synonyms = SynonymsCustom.append(SynonymsDictionaryFiltered, ignore_index=True)
Synonyms
# Out:
#                 Word        Word2
# 0                  €        euros
# 1     união europeia           ue
# 2       acção social  ação social
# 3         através do   através de
# 4         aumento da   aumento de
# ...              ...          ...
# 6580             zee          ZEE
# 6581            zees          ZEE
# 6582           zelam        zelar
# 6583           zonas         zona
# 6584        zoófilas      zoófilo
#
# [6585 rows x 2 columns]

# %%
WordList = FullWordList.merge(Synonyms, on=['Word'], how='left', indicator=True)
WordList
# Out:
#                                          Word Partido Q_Words Count  \
# 0                                   manifesto     PEV       1     1
# 1                                  ecologista     PEV       1     1
# 2                        manifesto ecologista     PEV       2     1
# 3                                   recuperar     PEV       1     1
# 4                                         voz     PEV       1     1
# ...                                       ...     ...     ...   ...
# 432662                       mundo mais justo     PCP       3     1
# 432663                    mais justo pacífico     PCP       3     1
# 432664            justo pacífico desenvolvido     PCP       3     1
# 432665      pacífico desenvolvido sustentável     PCP       3     1
# 432666  desenvolvido sustentável progressista     PCP       3     1
#
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 Word2     _merge
# 0              NaN           NaN             NaN   NaN  left_only
# 1              NaN           NaN             NaN   NaN  left_only
# 2              NaN           NaN             NaN   NaN  left_only
# 3              NaN           NaN             NaN   NaN  left_only
# 4              NaN           NaN             NaN   NaN  left_only
# ...            ...           ...             ...   ...        ...
# 432662    273043.0      164802.0        164802.0   NaN  left_only
# 432663    273044.0      164803.0        164803.0   NaN  left_only
# 432664    273045.0      164804.0        164804.0   NaN  left_only
# 432665    273046.0      164805.0        164805.0   NaN  left_only
# 432666    273047.0      164806.0        164806.0   NaN  left_only
#
# [432667 rows x 9 columns]

# %%
def GetSynonym(a, b):
    if pd.isna(b):
        return a
    else:
        return b

# %%
WordList['Word'] = WordList.apply(lambda x: GetSynonym(x['Word'], x['Word2']), axis = 1)
WordList.drop('_merge', axis = 1, inplace=True)
WordList.drop('Word2', axis = 1, inplace=True)
WordList.head(20)
# Out:
#                          Word Partido Q_Words Count  Unnamed: 0  Unnamed: 0.1  \
# 0                   manifesto     PEV       1     1         NaN           NaN
# 1                  ecologista     PEV       1     1         NaN           NaN
# 2        manifesto ecologista     PEV       2     1         NaN           NaN
# 3                   recuperar     PEV       1     1         NaN           NaN
# 4                         voz     PEV       1     1         NaN           NaN
# 5                  ecologista     PEV       1     1         NaN           NaN
# 6                  parlamento     PEV       1     1         NaN           NaN
# 7               recuperar voz     PEV       2     1         NaN           NaN
# 8              voz ecologista     PEV       2     1         NaN           NaN
# 9       ecologista parlamento     PEV       2     1         NaN           NaN
# 10   recuperar voz ecologista     PEV       3     1         NaN           NaN
# 11  voz ecologista parlamento     PEV       3     1         NaN           NaN
# 12                       vota     PEV       1     2         NaN           NaN
# 13                      verde     PEV       1     1         NaN           NaN
# 14                 vota verde     PEV       2     1         NaN           NaN
# 15                 verde vota     PEV       2     1         NaN           NaN
# 16            vota verde vota     PEV       3     1         NaN           NaN
# 17                        dia     PEV       1     1         NaN           NaN
# 18                      março     PEV       1     1         NaN           NaN
# 19                        não     PEV       1     1         NaN           NaN
#
#     Unnamed: 0.1.1
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN

# %%
WordListCount = WordList.groupby(['Partido', 'Word'])['Count'].sum().reset_index(name="Count")
WordListMin = WordList.groupby(['Partido', 'Word'])['Q_Words'].min().reset_index(name="Q_Words")
WordListCount = WordListCount.merge(WordListMin, on=['Partido', 'Word'], how='left', indicator=True)
WordListCount.drop('_merge', axis = 1, inplace=True)
WordListCount
# Out:
#        Partido                      Word  Count  Q_Words
# 0           BE                    #NAME?      8        1
# 1           BE                       % p      1        2
# 2           BE                    % p ib      1        3
# 3           BE               % realmente      1        2
# 4           BE     % realmente executado      1        3
# ...        ...                       ...    ...      ...
# 296699     PEV                    é voto      1        2
# 296700     PEV               é voto cdu!      1        3
# 296701     PEV                     órgão      1        1
# 296702     PEV          órgãos colegiais      1        2
# 296703     PEV  órgãos colegiais eleitos      1        3
#
# [296704 rows x 4 columns]

# %% [markdown]
# ## Criteria for word down-selection - density and min count

# %%
#Data = [[1.0,int(4000), int(225), 1],[2.0,int(1650), int(45), 2],[3.0,int(1250), int(25),4],[4.0,int(900), int(15),7]]
Data = [[1.0,int(4000), int(10), 1],[2.0,int(525), int(10), 2],[3.0,int(70), int(8),7],[4.0,int(7), int(5),5]]
WordCriteria = pd.DataFrame(Data, columns = ['Q_Words', 'Min_Density', 'Min_Count', 'Weight'])
WordCriteria
# Out:
#    Q_Words  Min_Density  Min_Count  Weight
# 0      1.0         4050         10       1
# 1      2.0          525         10       2
# 2      3.0           70          8       7
# 3      4.0            3          5       5

# %%
WordListDensity = WordListCount.merge(PartidoStats, on=['Partido'], how='left', indicator=True)
WordListDensity = WordListDensity.merge(WordCriteria, on=['Q_Words'], how='left')
WordListDensity['Density'] = WordListDensity.apply(lambda x: x['Count']*1000000/x['Count_Words'], axis = 1)
#WordListDensity

# %%
SelectedWordsPartido = WordListDensity[(WordListDensity['Density'] >  WordListDensity['Min_Density']) & (WordListDensity['Count'] >  WordListDensity['Min_Count'])]
SelectedWordsPartido.sort_values(by=['Density'],ascending=False)
# Out:
#        Partido                                               Word  Count  \
# 295409     PEV                                                não     23
# 142261      IL                                               mais    543
# 279235     PCP                                            público    287
# 188554      IL                                                  é    477
# 174598      IL                                                ser    454
# ...        ...                                                ...    ...
# 267661     PCP                     micro pequenas médias empresas      6
# 162816      IL  profissionais liberais trabalhadores independe...     10
# 43058       BE                           inquérito condições vida      9
# 136920      IL                       instituições ensino superior      9
# 42531       BE                       ine inquérito condições vida      6
#
#         Q_Words  Count_Words  Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 _merge  \
# 295409        1         1410           0             0               0   both
# 142261        1        38357       38357         38357               0   both
# 279235        1        22598       22598         22598           22598   both
# 188554        1        38357       38357         38357               0   both
# 174598        1        38357       38357         38357               0   both
# ...         ...          ...         ...           ...             ...    ...
# 267661        4        22598       22598         22598           22598   both
# 162816        4        38357       38357         38357               0   both
# 43058         3        36826       36826         36826           36826   both
# 136920        3        38357       38357         38357               0   both
# 42531         4        36826       36826         36826           36826   both
#
#         Min_Density  Min_Count  Weight       Density
# 295409         4050         10       1  16312.056738
# 142261         4050         10       1  14156.477305
# 279235         4050         10       1  12700.238959
# 188554         4050         10       1  12435.800506
# 174598         4050         10       1  11836.170712
# ...             ...        ...     ...           ...
# 267661            3          5       5    265.510222
# 162816            3          5       5    260.708606
# 43058            70          8       7    244.392549
# 136920           70          8       7    234.637745
# 42531             3          5       5    162.928366
#
# [147 rows x 13 columns]

# %%
ToExport = SelectedWordsPartido.copy()
#ToExport.drop('Q_Words', axis = 1, inplace=True)
ToExport['Weight_Count'] = ToExport['Count'] * ToExport['Weight']
ToExport['Weight_Density'] = ToExport['Density'] * ToExport['Weight']
#ToExport.drop('Count_Words', axis = 1, inplace=True)
ToExport.drop('_merge', axis = 1, inplace=True)
ToExport.drop('Unnamed: 0', axis = 1, inplace=True)
ToExport.drop('Unnamed: 0.1', axis = 1, inplace=True)
ToExport.drop('Min_Density', axis = 1, inplace=True)
ToExport.drop('Min_Count', axis = 1, inplace=True)
ToExport.sort_values(by=['Density'],ascending=False)
# Out:
#        Partido                                               Word  Count  \
# 295409     PEV                                                não     23
# 142261      IL                                               mais    543
# 279235     PCP                                            público    287
# 188554      IL                                                  é    477
# 174598      IL                                                ser    454
# ...        ...                                                ...    ...
# 267661     PCP                     micro pequenas médias empresas      6
# 162816      IL  profissionais liberais trabalhadores independe...     10
# 43058       BE                           inquérito condições vida      9
# 136920      IL                       instituições ensino superior      9
# 42531       BE                       ine inquérito condições vida      6
#
#         Q_Words  Count_Words  Unnamed: 0.1.1  Weight       Density  \
# 295409        1         1410               0       1  16312.056738
# 142261        1        38357               0       1  14156.477305
# 279235        1        22598           22598       1  12700.238959
# 188554        1        38357               0       1  12435.800506
# 174598        1        38357               0       1  11836.170712
# ...         ...          ...             ...     ...           ...
# 267661        4        22598           22598       5    265.510222
# 162816        4        38357               0       5    260.708606
# 43058         3        36826           36826       7    244.392549
# 136920        3        38357               0       7    234.637745
# 42531         4        36826           36826       5    162.928366
#
#         Weight_Count  Weight_Density
# 295409            23    16312.056738
# 142261           543    14156.477305
# 279235           287    12700.238959
# 188554           477    12435.800506
# 174598           454    11836.170712
# ...              ...             ...
# 267661            30     1327.551111
# 162816            50     1303.543030
# 43058             63     1710.747841
# 136920            63     1642.464218
# 42531             30      814.641829
#
# [147 rows x 10 columns]

# %% [markdown]
# Basic count to check if parties are reasonable represented on selected words

# %%
ToExport.groupby(['Partido','Q_Words'])['Word'].count()
# Out:
# Partido  Q_Words
# BE       1          12
#          2          10
#          3           4
#          4           1
# IL       1          14
#          2          17
#          3           5
#          4           1
# Livre    1          14
#          2          13
#          3           2
# PCP      1          20
#          2          27
#          3           2
#          4           2
# PEV      1           3
# Name: Word, dtype: int64

# %%
ToExport.to_csv('Word Density by Partido.txt', index=True, mode='w', header=True, encoding='utf-8-sig')

# %% [markdown]
# Another Nice Place to Restart - last minute update to word exclusion

# %%
ToExclude = pd.read_csv('2Exclude.txt')
ToExport = pd.read_csv('Word Density by Partido.txt')
ToExport#[['Count']>10]
# Out:
#      Unnamed: 0 Partido                             Word  Count  Q_Words  \
# 0           711      BE      2023 catarina reis oliveira      3        4
# 1          3917      BE            administração pública     33        2
# 2          4044      BE      adoção crianças mais velhas      3        4
# 3          8609      BE                  at g lance 2023      4        4
# 4         12537      BE                carta social mt s      3        4
# ..          ...     ...                              ...    ...      ...
# 213      292036     PCP  vida profissional vida familiar      3        4
# 214      292843     PCP                                é    121        1
# 215      294798     PEV                         garantir     15        1
# 216      295409     PEV                              não     23        1
# 217      296433     PEV                            todos     14        1
#
#      Count_Words  Unnamed: 0.1.1  Weight       Density  Weight_Count  \
# 0          36826           36826       7     81.464183            21
# 1          36826           36826       2    896.106012            66
# 2          36826           36826       7     81.464183            21
# 3          36826           36826       7    108.618911            28
# 4          36826           36826       7     81.464183            21
# ..           ...             ...     ...           ...           ...
# 213        22598           22598       7    132.755111            21
# 214        22598           22598       1   5354.456147           121
# 215         1410               0       1  10638.297872            15
# 216         1410               0       1  16312.056738            23
# 217         1410               0       1   9929.078014            14
#
#      Weight_Density
# 0        570.249280
# 1       1792.212024
# 2        570.249280
# 3        760.332374
# 4        570.249280
# ..              ...
# 213      929.285778
# 214     5354.456147
# 215    10638.297872
# 216    16312.056738
# 217     9929.078014
#
# [218 rows x 11 columns]

# %%
SelectedWords = ToExport.groupby(['Word'])['Word'].count().reset_index(name="Count")
SelectedWords.drop('Count', axis = 1, inplace=True)
SelectedWords = SelectedWords[~SelectedWords['Word'].isin(ToExclude['2Exclude'])]
SelectedWords
# Out:
#                            Word
# 0       (língua gestual línguas
# 1         0,43% novos contratos
# 2              0,43%, vez quase
# 4           1% orçamento estado
# 5     1,5ºc estabelecido acordo
# ...                         ...
# 1758                   é também
# 1759                é voto cdu!
# 1760   órgãos colegiais eleitos
# 1761                     último
# 1762                      único
#
# [1756 rows x 1 columns]

# %%
ToExport2 = SelectedWords.merge(WordListDensity, on=['Word'], how='left', indicator=False)
PartidoCount = ToExport2.groupby(['Partido'])['Partido'].count().reset_index(name="Count_Different")
ToExport2 = PartidoCount.merge(ToExport2, on=['Partido'], how='left', indicator=False)
ToExport2
# Out:
#     Partido  Count_Different                    Word  Count  Q_Words  \
# 0        BE              101       abandono  escolar      4        2
# 1        BE              101                  acesso    101        1
# 2        BE              101  administração  pública     14        2
# 3        BE              101                  animal     42        1
# 4        BE              101                   apoio    111        1
# ..      ...              ...                     ...    ...      ...
# 887     PSD              106                    todo    149        1
# 888     PSD              106               trabalhar     73        1
# 889     PSD              106                       é    394        1
# 890     PSD              106            é  essencial      6        2
# 891     PSD              106           é  necessário     28        2
#
#      Unnamed: 0  Count_Words  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0         38763        38763         38763           38763             38763
# 1         38763        38763         38763           38763             38763
# 2         38763        38763         38763           38763             38763
# 3         38763        38763         38763           38763             38763
# 4         38763        38763         38763           38763             38763
# ..          ...          ...           ...             ...               ...
# 887       38165        38165         38165           38165             38165
# 888       38165        38165         38165           38165             38165
# 889       38165        38165         38165           38165             38165
# 890       38165        38165         38165           38165             38165
# 891       38165        38165         38165           38165             38165
#
#      Unnamed: 0.1.1.1.1 _merge  Min_Density  Min_Count  Weight       Density
# 0                 38763   both         1650         45       2    103.191187
# 1                 38763   both         4000        225       1   2605.577484
# 2                 38763   both         1650         45       2    361.169156
# 3                 38763   both         4000        225       1   1083.507468
# 4                 38763   both         4000        225       1   2863.555452
# ..                  ...    ...          ...        ...     ...           ...
# 887                   0   both         4000        225       1   3904.100616
# 888                   0   both         4000        225       1   1912.747282
# 889                   0   both         4000        225       1  10323.594917
# 890                   0   both         1650         45       2    157.212105
# 891                   0   both         1650         45       2    733.656492
#
# [892 rows x 16 columns]

# %% [markdown]
# ## Cross Pivot so that words are columns (dimensions)

# %%
DensityPivot = ToExport2.pivot(index=['Partido', 'Count_Words', 'Count_Different'],columns='Word', values='Density')
DensityPivot = DensityPivot.fillna(0)
DensityPivot.to_csv('Data for Clustering - Density.txt', index=True, mode='w', header=True, encoding='utf-8-sig')
DensityPivot
# Out:
# Word                                 abandono  escolar       acesso  \
# Partido Count_Words Count_Different
# BE      38763       101                     103.191187  2605.577484
# CDS     1876        82                        0.000000  1066.098081
# CH      2309        86                        0.000000  2165.439584
# IL      102905      108                     524.755843  3167.970458
# Livre   20294       102                       0.000000  3449.295358
# PAN     31879       103                      94.105838  2572.226230
# PCP     28417       104                      70.380406  2287.363198
# PS      32349       100                      30.912857  3184.024236
# PSD     38165       106                      26.202018  1807.939211
#
# Word                                 administração  pública       animal  \
# Partido Count_Words Count_Different
# BE      38763       101                          361.169156  1083.507468
# CDS     1876        82                             0.000000     0.000000
# CH      2309        86                             0.000000     0.000000
# IL      102905      108                         1098.100189   437.296536
# Livre   20294       102                          788.410368  2463.782399
# PAN     31879       103                          564.635026  9096.897644
# PCP     28417       104                         1126.086498     0.000000
# PS      32349       100                         1916.597113   123.651427
# PSD     38165       106                         1100.484737   288.222193
#
# Word                                       apoio  \
# Partido Count_Words Count_Different
# BE      38763       101              2863.555452
# CDS     1876        82               4264.392324
# CH      2309        86               1299.263751
# IL      102905      108              1613.138331
# Livre   20294       102              3252.192766
# PAN     31879       103              3293.704319
# PCP     28417       104              3167.118274
# PS      32349       100              5564.314198
# PSD     38165       106              3118.040089
#
# Word                                 atingir  objetivos  desenvolvimento  \
# Partido Count_Words Count_Different
# BE      38763       101                                          0.00000
# CDS     1876        82                                           0.00000
# CH      2309        86                                           0.00000
# IL      102905      108                                          0.00000
# Livre   20294       102                                          0.00000
# PAN     31879       103                                        972.42699
# PCP     28417       104                                          0.00000
# PS      32349       100                                          0.00000
# PSD     38165       106                                          0.00000
#
# Word                                     através      aumento          bem  \
# Partido Count_Words Count_Different
# BE      38763       101              1754.250187  2631.375281  1547.867812
# CDS     1876        82                533.049041  2132.196162  1599.147122
# CH      2309        86               2165.439584  2165.439584  3464.703335
# IL      102905      108              1826.927749  2332.248190  2167.047277
# Livre   20294       102              5814.526461  1379.718143  3794.224894
# PAN     31879       103              2446.751780  1976.222592  4297.499922
# PCP     28417       104              3624.590914  2604.075026  2005.841574
# PS      32349       100              4853.318495  2658.505673  2287.551393
# PSD     38165       106              3196.646142  2174.767457  4035.110704
#
# Word                                  bem  estar  ...        sobre  \
# Partido Count_Words Count_Different               ...
# BE      38763       101               283.775766  ...  3431.106983
# CDS     1876        82               1066.098081  ...  2665.245203
# CH      2309        86                  0.000000  ...  1732.351667
# IL      102905      108               194.354016  ...  3488.654584
# Livre   20294       102              1773.923327  ...  3055.090174
# PAN     31879       103              2101.697042  ...  2603.594843
# PCP     28417       104                 0.000000  ...  1618.749340
# PS      32349       100               247.302853  ...  1576.555690
# PSD     38165       106               445.434298  ...  1755.535176
#
# Word                                       social   socialismo       também  \
# Partido Count_Words Count_Different
# BE      38763       101               6243.066842     0.000000  2012.228156
# CDS     1876        82                6396.588486     0.000000  1599.147122
# CH      2309        86               16024.252923  7362.494586   433.087917
# IL      102905      108               3294.300568    29.153102  2895.874836
# Livre   20294       102               6356.558589    49.275648  1921.750271
# PAN     31879       103               3732.864895     0.000000  1693.905079
# PCP     28417       104               5982.334518     0.000000  1513.178731
# PS      32349       100               6151.658475     0.000000  2318.464249
# PSD     38165       106               6183.676143     0.000000  3458.666317
#
# Word                                         tem         todo    trabalhar  \
# Partido Count_Words Count_Different
# BE      38763       101              3921.265124  4127.647499  3998.658515
# CDS     1876        82               1599.147122  7995.735608  1599.147122
# CH      2309        86                433.087917  2598.527501  1299.263751
# IL      102905      108              4888.003498  3955.104222  1992.128662
# Livre   20294       102              1823.198975  7687.001084  4730.462206
# PAN     31879       103              3105.492644  7748.047304  2666.332068
# PCP     28417       104              3976.492944  3413.449696  2041.031777
# PS      32349       100              1143.775696  4915.144208  3462.239946
# PSD     38165       106              4742.565178  3904.100616  1912.747282
#
# Word                                            é  é  essencial  é  necessário
# Partido Count_Words Count_Different
# BE      38763       101               8719.655341     51.595594     438.562547
# CDS     1876        82                5863.539446    533.049041       0.000000
# CH      2309        86                5630.142919      0.000000       0.000000
# IL      102905      108              11282.250620    553.908945     719.109859
# Livre   20294       102               3991.327486    147.826944     591.307776
# PAN     31879       103               5803.193325    345.054738     501.897801
# PCP     28417       104               9958.827462    175.951015     527.853046
# PS      32349       100               4204.148505    340.041423     247.302853
# PSD     38165       106              10323.594917    157.212105     733.656492
#
# [9 rows x 121 columns]

# %%
CountPivot = ToExport2.pivot(index='Partido',columns='Word', values='Count')
CountPivot = CountPivot.fillna(0)
CountPivot.to_csv('Data for Clustering - Count.txt', index=True, mode='w', header=True, encoding='utf-8-sig')
CountPivot
# Out:
# Word     abandono  escolar  acesso  administração  pública  animal  apoio  \
# Partido
# BE                     4.0   101.0                    14.0    42.0  111.0
# CDS                    0.0     2.0                     0.0     0.0    8.0
# CH                     0.0     5.0                     0.0     0.0    3.0
# IL                    54.0   326.0                   113.0    45.0  166.0
# Livre                  0.0    70.0                    16.0    50.0   66.0
# PAN                    3.0    82.0                    18.0   290.0  105.0
# PCP                    2.0    65.0                    32.0     0.0   90.0
# PS                     1.0   103.0                    62.0     4.0  180.0
# PSD                    1.0    69.0                    42.0    11.0  119.0
#
# Word     atingir  objetivos  desenvolvimento  através  aumento    bem  \
# Partido
# BE                                       0.0     68.0    102.0   60.0
# CDS                                      0.0      1.0      4.0    3.0
# CH                                       0.0      5.0      5.0    8.0
# IL                                       0.0    188.0    240.0  223.0
# Livre                                    0.0    118.0     28.0   77.0
# PAN                                     31.0     78.0     63.0  137.0
# PCP                                      0.0    103.0     74.0   57.0
# PS                                       0.0    157.0     86.0   74.0
# PSD                                      0.0    122.0     83.0  154.0
#
# Word     bem  estar  ...  sobre  social  socialismo  também    tem   todo  \
# Partido              ...
# BE             11.0  ...  133.0   242.0         0.0    78.0  152.0  160.0
# CDS             2.0  ...    5.0    12.0         0.0     3.0    3.0   15.0
# CH              0.0  ...    4.0    37.0        17.0     1.0    1.0    6.0
# IL             20.0  ...  359.0   339.0         3.0   298.0  503.0  407.0
# Livre          36.0  ...   62.0   129.0         1.0    39.0   37.0  156.0
# PAN            67.0  ...   83.0   119.0         0.0    54.0   99.0  247.0
# PCP             0.0  ...   46.0   170.0         0.0    43.0  113.0   97.0
# PS              8.0  ...   51.0   199.0         0.0    75.0   37.0  159.0
# PSD            17.0  ...   67.0   236.0         0.0   132.0  181.0  149.0
#
# Word     trabalhar       é  é  essencial  é  necessário
# Partido
# BE           155.0   338.0           2.0           17.0
# CDS            3.0    11.0           1.0            0.0
# CH             3.0    13.0           0.0            0.0
# IL           205.0  1161.0          57.0           74.0
# Livre         96.0    81.0           3.0           12.0
# PAN           85.0   185.0          11.0           16.0
# PCP           58.0   283.0           5.0           15.0
# PS           112.0   136.0          11.0            8.0
# PSD           73.0   394.0           6.0           28.0
#
# [9 rows x 121 columns]

# %%
FinalPivot = DensityPivot.merge(CountPivot, on=['Partido'], how='left', indicator=True)
FinalPivot.drop('_merge', axis = 1, inplace=True)
FinalPivot = FinalPivot.fillna(0)
FinalPivot
# Out:
# Word     abandono  escolar_x     acesso_x  administração  pública_x  \
# Partido
# BE                103.191187  2605.577484                361.169156
# CDS                 0.000000  1066.098081                  0.000000
# CH                  0.000000  2165.439584                  0.000000
# IL                524.755843  3167.970458               1098.100189
# Livre               0.000000  3449.295358                788.410368
# PAN                94.105838  2572.226230                564.635026
# PCP                70.380406  2287.363198               1126.086498
# PS                 30.912857  3184.024236               1916.597113
# PSD                26.202018  1807.939211               1100.484737
#
# Word        animal_x      apoio_x  atingir  objetivos  desenvolvimento_x  \
# Partido
# BE       1083.507468  2863.555452                                0.00000
# CDS         0.000000  4264.392324                                0.00000
# CH          0.000000  1299.263751                                0.00000
# IL        437.296536  1613.138331                                0.00000
# Livre    2463.782399  3252.192766                                0.00000
# PAN      9096.897644  3293.704319                              972.42699
# PCP         0.000000  3167.118274                                0.00000
# PS        123.651427  5564.314198                                0.00000
# PSD       288.222193  3118.040089                                0.00000
#
# Word       através_x    aumento_x        bem_x  bem  estar_x  ...  sobre_y  \
# Partido                                                       ...
# BE       1754.250187  2631.375281  1547.867812    283.775766  ...    133.0
# CDS       533.049041  2132.196162  1599.147122   1066.098081  ...      5.0
# CH       2165.439584  2165.439584  3464.703335      0.000000  ...      4.0
# IL       1826.927749  2332.248190  2167.047277    194.354016  ...    359.0
# Livre    5814.526461  1379.718143  3794.224894   1773.923327  ...     62.0
# PAN      2446.751780  1976.222592  4297.499922   2101.697042  ...     83.0
# PCP      3624.590914  2604.075026  2005.841574      0.000000  ...     46.0
# PS       4853.318495  2658.505673  2287.551393    247.302853  ...     51.0
# PSD      3196.646142  2174.767457  4035.110704    445.434298  ...     67.0
#
# Word     social_y  socialismo_y  também_y  tem_y  todo_y  trabalhar_y     é_y  \
# Partido
# BE          242.0           0.0      78.0  152.0   160.0        155.0   338.0
# CDS          12.0           0.0       3.0    3.0    15.0          3.0    11.0
# CH           37.0          17.0       1.0    1.0     6.0          3.0    13.0
# IL          339.0           3.0     298.0  503.0   407.0        205.0  1161.0
# Livre       129.0           1.0      39.0   37.0   156.0         96.0    81.0
# PAN         119.0           0.0      54.0   99.0   247.0         85.0   185.0
# PCP         170.0           0.0      43.0  113.0    97.0         58.0   283.0
# PS          199.0           0.0      75.0   37.0   159.0        112.0   136.0
# PSD         236.0           0.0     132.0  181.0   149.0         73.0   394.0
#
# Word     é  essencial_y  é  necessário_y
# Partido
# BE                  2.0             17.0
# CDS                 1.0              0.0
# CH                  0.0              0.0
# IL                 57.0             74.0
# Livre               3.0             12.0
# PAN                11.0             16.0
# PCP                 5.0             15.0
# PS                 11.0              8.0
# PSD                 6.0             28.0
#
# [9 rows x 242 columns]

# %%
FinalPivot.to_csv('Data for Clustering.txt', index=True, mode='w', header=True, encoding='utf-8-sig')
